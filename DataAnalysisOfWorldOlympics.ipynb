# %% [markdown]
# # Summer Olympics Data Analysis Assignment
# <img src="olympics.png" width="700px">

# %% [markdown]
# ### Importing Important Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv("summer.csv")

# %% [markdown]
# ### Viewing Dataset

# %%
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
#Names of the unique cities in which summer olympics is held
pd.DataFrame(pd.unique(df['City']))
# Out:
#                         0
# 0                  Athens
# 1                   Paris
# 2                St Louis
# 3                  London
# 4               Stockholm
# 5                 Antwerp
# 6               Amsterdam
# 7             Los Angeles
# 8                  Berlin
# 9                Helsinki
# 10  Melbourne / Stockholm
# 11                   Rome
# 12                  Tokyo
# 13                 Mexico
# 14                 Munich
# 15               Montreal
# 16                 Moscow
# 17                  Seoul
# 18              Barcelona
# 19                Atlanta
# 20                 Sydney
# 21                Beijing

# %%
#Count of the Cities where Summer Olympics is held so far
count = len(pd.unique(df['City']))
print("Answer: Count of cities where Summer Olympics is held so far =", count)
# Out:
# Answer: Count of cities where Summer Olympics is held so far = 22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
#List of only those sports where Gold medal is won
golddf = df.where(df['Medal']=='Gold').dropna()
golddf
# Out:
#          Year    City      Sport           Discipline  \
# 0      1896.0  Athens   Aquatics             Swimming
# 3      1896.0  Athens   Aquatics             Swimming
# 6      1896.0  Athens   Aquatics             Swimming
# 9      1896.0  Athens   Aquatics             Swimming
# 13     1896.0  Athens  Athletics            Athletics
# ...       ...     ...        ...                  ...
# 31145  2012.0  London  Wrestling  Wrestling Freestyle
# 31149  2012.0  London  Wrestling  Wrestling Freestyle
# 31153  2012.0  London  Wrestling  Wrestling Freestyle
# 31157  2012.0  London  Wrestling  Wrestling Freestyle
# 31161  2012.0  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
data1 = []

for Sport in golddf['Sport'].unique():
    data1.append([Sport , len(golddf[golddf['Sport']  == Sport])])

pd.DataFrame(data1,columns = ['Sport','Count']).sort_values(by='Count', ascending=False).head().plot(x = 'Sport', y = 'Count', xlabel ='Sport', ylabel='Number of Gold medals won', kind = 'bar', figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Sport', ylabel='Number of Gold medals won'>

# %%
pd.DataFrame(data1,columns = ['Sport','Count']).sort_values(by='Count', ascending=False).reset_index(drop=True).head()
# Out:
#         Sport  Count
# 0    Aquatics   1421
# 1   Athletics   1214
# 2      Rowing    890
# 3  Gymnastics    820
# 4     Fencing    552

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
data2 = []

for Sport in df['Sport'].unique():
    data2.append([Sport , len(df[df['Sport']  == Sport])])

pd.DataFrame(data2,columns = ['Sport','Count']).sort_values(by='Count', ascending=False).head().plot(x = 'Sport', y = 'Count', xlabel ='Sport', ylabel='Number of medals won', kind = 'bar', figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Sport', ylabel='Number of medals won'>

# %%
pd.DataFrame(data2,columns = ['Sport','Count']).sort_values(by='Count', ascending=False).reset_index(drop=True).head()
# Out:
#         Sport  Count
# 0    Aquatics   4170
# 1   Athletics   3638
# 2      Rowing   2667
# 3  Gymnastics   2307
# 4     Fencing   1613

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
data3 = []

for Athlete in df['Athlete'].unique():
    data3.append([Athlete , len(df[df['Athlete']  == Athlete])])

pd.DataFrame(data3,columns = ['Athlete','Count']).sort_values(by='Count', ascending=False).head().plot(x = 'Athlete', y = 'Count', xlabel ='Athlete', ylabel='Number of medals won', kind = 'bar', figsize = (15,5))
# Out:
# <AxesSubplot:xlabel='Athlete', ylabel='Number of medals won'>

# %%
pd.DataFrame(data3,columns = ['Athlete','Count']).sort_values(by='Count', ascending=False).reset_index(drop = True).head()
# Out:
#                 Athlete  Count
# 0       PHELPS, Michael     22
# 1      LATYNINA, Larisa     18
# 2    ANDRIANOV, Nikolay     15
# 3          ONO, Takashi     13
# 4  MANGIAROTTI, Edoardo     13

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
data4 = []

for Athlete in golddf['Athlete'].unique():
    data4.append([Athlete , len(golddf[golddf['Athlete']  == Athlete])])

pd.DataFrame(data4,columns = ['Athlete','Count']).sort_values(by='Count', ascending=False).head().plot(x = 'Athlete', y = 'Count', xlabel ='Athlete', ylabel='Number of Gold medals won', kind = 'bar', figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Athlete', ylabel='Number of Gold medals won'>

# %%
pd.DataFrame(data4,columns = ['Athlete','Count']).sort_values(by='Count', ascending=False).reset_index(drop = True).head()
# Out:
#             Athlete  Count
# 0   PHELPS, Michael     18
# 1       LEWIS, Carl      9
# 2      NURMI, Paavo      9
# 3  LATYNINA, Larisa      9
# 4       SPITZ, Mark      9

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
golddf.where(df['Country']=='IND').dropna().head(1)
# Out:
#         Year       City   Sport Discipline               Athlete Country  \
# 5512  1928.0  Amsterdam  Hockey     Hockey  ALLEN, Richard James     IND
#
#      Gender   Event Medal
# 5512    Men  Hockey  Gold

# %% [markdown]
# India won the first Gold Medal in the year 1928.

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
y = df.loc[:, ['Sport', 'Athlete']].drop_duplicates()
data6 = []

for Sport in y['Sport'].unique():
    data6.append([Sport , len(y[y['Sport']  == Sport])])
pd.DataFrame(data6,columns = ['Sport','Count']).sort_values(by='Count', ascending=False).reset_index(drop = True).head().plot(x = 'Sport', y = 'Count', xlabel ='Athlete', ylabel='Number of Athletes', kind = 'bar', figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Athlete', ylabel='Number of Athletes'>

# %%
pd.DataFrame(data6,columns = ['Sport','Count']).sort_values(by='Count', ascending=False).reset_index(drop = True).head()
# Out:
#         Sport  Count
# 0   Athletics   2655
# 1    Aquatics   2516
# 2      Rowing   2177
# 3  Gymnastics   1401
# 4    Football   1357

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
x =golddf.loc[:, ['Sport', 'Athlete','Gender']].drop_duplicates()
x[x["Gender"]=='Women']
# Out:
#                Sport                Athlete Gender
# 417             Golf  ABBOTT, Margaret Ives  Women
# 641           Tennis      COOPER, Charlotte  Women
# 710          Archery  HOWELL, Matilda Scott  Women
# 731          Archery        POLLOCK, Jessie  Women
# 732          Archery         TAYLOR, Louise  Women
# ...              ...                    ...    ...
# 31066  Weightlifting            LI, Xueying  Women
# 31078  Weightlifting          RIM, Jong Sim  Women
# 31081  Weightlifting  VALENTIN PEREZ, Lidia  Women
# 31097      Wrestling          OBARA, Hitomi  Women
# 31121      Wrestling     VOROBIEVA, Natalia  Women
#
# [2049 rows x 3 columns]

# %%
data5 = []

for Sport in x['Sport'].unique():
    data5.append([Sport , len(x[x['Sport']  == Sport])])
pd.DataFrame(data5,columns = ['Sport','Count']).sort_values(by='Count', ascending=False).reset_index(drop = True).head().plot(x = 'Sport', y = 'Count', xlabel ='Athlete', ylabel='Number of Female Gold medalist', kind = 'bar', figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Athlete', ylabel='Number of Female Gold medalist'>

# %%
pd.DataFrame(data5,columns = ['Sport','Count']).sort_values(by='Count', ascending=False).reset_index(drop = True).head()
# Out:
#         Sport  Count
# 0    Aquatics    951
# 1   Athletics    942
# 2      Rowing    752
# 3  Gymnastics    566
# 4    Football    465
